# %%
import pandas as pd

# %% [markdown]
# Find the counties that have released the highest proportion of their population

# %%
jr = pd.read_csv('covid_jail_releases.csv')
jr = jr.iloc[1:,:7] # jail releases

# rename columns for ease of use
jr.rename(columns={'Overall Pop. Reduction / \nTotal Number of Releases':'releases',
                  'Population Prior to Releases':'prior_pop'},
          inplace=True)

# some rows have weird entries (range of values, circa values), remove
jr = jr[jr['releases'].astype(str).apply(lambda x: x.isnumeric())]
jr = jr[jr['prior_pop'].astype(str).apply(lambda x: x.isnumeric())]

# make columns numeric
jr['releases'] = pd.to_numeric(jr['releases'])
jr['prior_pop'] = pd.to_numeric(jr['prior_pop'])

# what fraction of the prior population has been released
jr['frac_reduction'] = jr['releases']/jr['prior_pop']

# %%
jr.sort_values('frac_reduction',ascending = False)
# Out:
#               State           County                             Facility  \
# 28  District of Col          DC jail                              DC jail
# 76           Oregon           Marion                          County-wide
# 41             Iowa             Polk                          County-wide
# 77           Oregon        Multnomah                          County-wide
# 73           Oregon          Douglas                          County-wide
# 19       California        San Diego                           Ocean View
# 70           Oregon       Washington                          County-wide
# 72           Oregon        Deschutes                          County-wide
# 99        Wisconsin       Eau Claire                          County-wide
# 97        Wisconsin         Chippewa                          County-wide
# 68             Ohio         Hamilton                          County-wide
# 42         Kentucky              All                           State-wide
# 75           Oregon        Josephine                          County-wide
# 55        Minnesota         Hennepin                          County-wide
# 74           Oregon        Jefferson                          County-wide
# 23       California        San Mateo                          County-wide
# 56        Minnesota           Ramsey                          County-wide
# 52         MIchigan            Wayne                          County-wide
# 71           Oregon            Crook                          County-wide
# 36           Hawaii             Maui   Maui Community Correctional Center
# 35           Hawaii             All                            State-wide
# 45            Maine              all                           State-wide
# 92       Washington            Clark                    Clark County Jail
# 86        Tennessee         Anderson                          County-wide
# 83     Pennsylvania   Northumberland           Northumberland County Jail
# 67             Ohio         Franklin                          County-wide
# 13       California      Los Angeles                          County-wide
# 2           Alabama           Mobile                    Mobile Metro Jail
# 5           Arizona         Maricopa                          County-wide
# 21       California         Monterey                          County-wide
# ..              ...              ...                                  ...
# 51         Michigan            Wayne                                  NaN
# 90         Virginia        Arlington                          County-wide
# 17       California    San Francisco                          County-wide
# 26         Colorado           Denver                      Denver Cty jail
# 64   North Carolina           Centre  Centre County Correctional Facility
# 20       California            Marin                          County jail
# 78           Oregon             Polk                          County-wide
# 16       California          Alameda                                  NaN
# 88            Texas           Harris                          County-wide
# 87            Texas           Dallas                          County-wide
# 25       California           Orange                          County-wide
# 37         Illinois             Cook                                  NaN
# 49    Massachusetts       State-wide                           State-wide
# 53         Michigan          Oakland                                  NaN
# 33          Florida          Broward                          County-wide
# 81     Pennsylvania     Philadelphia                          county-wide
# 85   South Carolina         Anderson                            County DC
# 12       California          Alameda                           Santa Rita
# 4           Arizona         Cococino                                  NaN
# 48         Maryland  Prince George's                          County jail
# 84   South Carolina       Greenville                            County DC
# 9          Arkansas       Washington               Washington County Jail
# 30          Florida     Hillsborough                          County-wide
# 59         New York              NYC                            city-wide
# 89            Texas          Travis                           County-wide
# 57           Nevada     Clark County                          County-wide
# 60         New York              NYC                            City-wide
# 6           Arizona      Pima County                          County-wide
# 62         New York              NYC                            City-wide
# 61         New York              NYC                            City-wide
#
#                   Authorizing Agent  Known Capacity \n(if available)  \
# 28                              NaN                              NaN
# 76                              NaN                              NaN
# 41                              NaN                              NaN
# 77                  Sheriff, courts                           1192.0
# 73                              NaN                              NaN
# 19                              NaN                              NaN
# 70                              NaN                              NaN
# 72                              NaN                              NaN
# 99                          Sheriff                              NaN
# 97                          Sheriff                              NaN
# 68                  Sheriff, courts                              NaN
# 42                              NaN                              NaN
# 75                              NaN                              NaN
# 55                              NaN                              NaN
# 74                              NaN                              NaN
# 23                              NaN                           1500.0
# 56  Courts with prosecutor consent                               NaN
# 52                              NaN                              NaN
# 71                              NaN                              NaN
# 36                          Courts                             301.0
# 35                           Courts                              NaN
# 45                              NaN                              NaN
# 92                              NaN                              NaN
# 86                              NaN                              NaN
# 83                              NaN                              NaN
# 67                  Sheriff, Courts                           2330.0
# 13                              NaN                              NaN
# 2                          Governor                              NaN
# 5                               NaN                              NaN
# 21                              NaN                              NaN
# ..                              ...                              ...
# 51                              NaN                              NaN
# 90                              NaN                              NaN
# 17                 Joint Initiative                              NaN
# 26                              NaN                              NaN
# 64                              NaN                            397.0
# 20                     Court/others                              NaN
# 78                              NaN                              NaN
# 16                              NaN                              NaN
# 88                              NaN                              NaN
# 87                           Courts                              NaN
# 25                            Court                              NaN
# 37                    some by court                              NaN
# 49                              NaN                              NaN
# 53                              NaN                              NaN
# 33                              NaN                              NaN
# 81                              NaN                              NaN
# 85                              NaN                              NaN
# 12                            Court                              NaN
# 4                             Court                              NaN
# 48    Courts with State's Attorney                            1524.0
# 84                           Courts                              NaN
# 9                               NaN                            710.0
# 30                          Sheriff                              NaN
# 59                            Mayor                              NaN
# 89                           courts                              NaN
# 57                              NaN                              NaN
# 60                         Governor                              NaN
# 6                             Court                           2300.0
# 62                           Courts                              NaN
# 61                           Courts                              NaN
#
#     prior_pop  releases  frac_reduction
# 28       1850      1442        0.779459
# 76        415       300        0.722892
# 41       1000       700        0.700000
# 77       1097       739        0.673655
# 73        194       128        0.659794
# 19         55        34        0.618182
# 70        573       300        0.523560
# 72        289       148        0.512111
# 99        281       143        0.508897
# 97        100        50        0.500000
# 68       1600       750        0.468750
# 42      11500      5184        0.450783
# 75        170        75        0.441176
# 55        815       359        0.440491
# 74         60        24        0.400000
# 23        969       382        0.394221
# 56        393       153        0.389313
# 52       1410       534        0.378723
# 71         48        18        0.375000
# 36        450       167        0.371111
# 35       2189       811        0.370489
# 45       1800       650        0.361111
# 92        601       200        0.332779
# 86        415       135        0.325301
# 83        277        88        0.317690
# 67       1960       609        0.310714
# 13      17076      5193        0.304111
# 2        1580       480        0.303797
# 5        7500      2200        0.293333
# 21        885       244        0.275706
# ..        ...       ...             ...
# 51       1400       384        0.274286
# 90        307        81        0.263844
# 17       1100       260        0.236364
# 26       2000       450        0.225000
# 64        195        43        0.220513
# 20        270        58        0.214815
# 78        120        24        0.200000
# 16       2500       500        0.200000
# 88       9059      1789        0.197483
# 87       5879      1000        0.170097
# 25       5289       838        0.158442
# 37       5500       860        0.156364
# 49       7173      1081        0.150704
# 53       1079       152        0.140871
# 33       3600       400        0.111111
# 81       4780       531        0.111088
# 85        387        42        0.108527
# 12       2500       247        0.098800
# 4         550        50        0.090909
# 48        723        50        0.069156
# 84       1270        85        0.066929
# 9         408        25        0.061275
# 30       2700       164        0.060741
# 59       5300       300        0.056604
# 89       2164        97        0.044824
# 57       2900       115        0.039655
# 60       5000       106        0.021200
# 6        1760        27        0.015341
# 62       4300        51        0.011860
# 61       4400        28        0.006364
#
# [61 rows x 8 columns]

# %%
nyt_data = pd.read_csv('NYT_data/us-counties.csv')

# %%
sort(list(nyt_data['county'].unique())
# Out:
# ['Snohomish',
#  'Cook',
#  'Orange',
#  'Maricopa',
#  'Los Angeles',
#  'Santa Clara',
#  'Suffolk',
#  'San Francisco',
#  'Dane',
#  'San Diego',
#  'Bexar',
#  'Douglas',
#  'Humboldt',
#  'Sacramento',
#  'Solano',
#  'Spokane',
#  'Salt Lake',
#  'Marin',
#  'Napa',
#  'Sonoma',
#  'Washington',
#  'King',
#  'Alameda',
#  'Hillsborough',
#  'Manatee',
#  'New York City',
#  'Unknown',
#  'Placer',
#  'San Mateo',
#  'Fulton',
#  'Norfolk',
#  'Grafton',
#  'Walla Walla',
#  'Contra Costa',
#  'Wake',
#  'Bergen',
#  'Westchester',
#  'Fort Bend',
#  'Chelan',
#  'Jefferson',
#  'Santa Rosa',
#  'Montgomery',
#  'Middlesex',
#  'Clark',
#  'Washoe',
#  'Nassau',
#  'Williamson',
#  'Harris',
#  'Pinal',
#  'Yolo',
#  'Denver',
#  'Eagle',
#  'El Paso',
#  'Broward',
#  'Lee',
#  'Polk',
#  'Honolulu',
#  'Marion',
#  'Fayette',
#  'Ramsey',
#  'Camden',
#  'Rockland',
#  'Chatham',
#  'Tulsa',
#  'Delaware',
#  'Wayne',
#  'Charleston',
#  'Kershaw',
#  'Davis',
#  'Pierce',
#  'Fresno',
#  'Madera',
#  'Riverside',
#  'Santa Cruz',
#  'District of Columbia',
#  'Charlotte',
#  'Okaloosa',
#  'Volusia',
#  'Cobb',
#  'Gwinnett',
#  'Johnson',
#  'Berkshire',
#  'St. Louis',
#  'Rockingham',
#  'Saratoga',
#  'Jackson',
#  'Klamath',
#  'Bennington',
#  'Fairfax',
#  'Kittitas',
#  'Fairfield',
#  'Cherokee',
#  'Hendricks',
#  'Harrison',
#  'Harford',
#  'Worcester',
#  'Carver',
#  'Passaic',
#  'Ulster',
#  'Spartanburg',
#  'Davidson',
#  'Shelby',
#  'Kitsap',
#  'Pima',
#  'Shasta',
#  'Arapahoe',
#  'Larimer',
#  'DeKalb',
#  'Floyd',
#  'Noble',
#  'Pottawattamie',
#  "Prince George's",
#  'Hudson',
#  'Monmouth',
#  'Union',
#  'Cuyahoga',
#  'Monroe',
#  'Collin',
#  'Virginia Beach city',
#  'San Joaquin',
#  'Ventura',
#  'Gunnison',
#  'Alachua',
#  'Collier',
#  'Pasco',
#  'Pinellas',
#  'Charlton',
#  'Kane',
#  'McHenry',
#  'Adams',
#  'Boone',
#  'Orleans',
#  'Essex',
#  'Oakland',
#  'Anoka',
#  'Burlington',
#  'Multnomah',
#  'Philadelphia',
#  'Beadle',
#  'Charles Mix',
#  'Davison',
#  'Minnehaha',
#  'Sullivan',
#  'Dallas',
#  'Tarrant',
#  'Weber',
#  'Loudoun',
#  'Skagit',
#  'Whatcom',
#  'Stanislaus',
#  'Pitkin',
#  'New Castle',
#  'Miami-Dade',
#  'St. Johns',
#  'Bartow',
#  'Lowndes',
#  'Lake',
#  'Howard',
#  'St. Joseph',
#  'Caddo',
#  'Baltimore',
#  'Olmsted',
#  'Forrest',
#  'Bernalillo',
#  'Santa Fe',
#  'Socorro',
#  'Ward',
#  'Stark',
#  'Deschutes',
#  'Linn',
#  'Umatilla',
#  'Bucks',
#  'Lancaster',
#  'Bon Homme',
#  'Gregg',
#  'Chittenden',
#  'Arlington',
#  'Island',
#  'Thurston',
#  'Fond du Lac',
#  'Waukesha',
#  'Sheridan',
#  'Anchorage',
#  'Pulaski',
#  'Tulare',
#  'Litchfield',
#  'Clay',
#  'Duval',
#  'Palm Beach',
#  'Sarasota',
#  'Seminole',
#  'Carroll',
#  'Wyandotte',
#  'Androscoggin',
#  'Ingham',
#  'Kent',
#  'Montcalm',
#  'St. Clair',
#  'Washtenaw',
#  'Dakota',
#  'Hennepin',
#  'Stearns',
#  'Greene',
#  'Cass',
#  'Carson City',
#  'Morris',
#  'Albany',
#  'Dutchess',
#  'Herkimer',
#  'Cabarrus',
#  'Forsyth',
#  'Johnston',
#  'Mecklenburg',
#  'Onslow',
#  'Trumbull',
#  'Clackamas',
#  'Northampton',
#  'Pike',
#  'Knox',
#  'Alexandria city',
#  'Hanover',
#  'James City',
#  'Prince Edward',
#  'Prince William',
#  'Columbia',
#  'Grays Harbor',
#  'Yakima',
#  'Elmore',
#  'Limestone',
#  'Tuscaloosa',
#  'San Benito',
#  'Clear Creek',
#  'Pueblo',
#  'Routt',
#  'Summit',
#  'Weld',
#  'Osceola',
#  'Gordon',
#  'Henry',
#  'Ada',
#  'Butler',
#  'St. Charles',
#  'St. Tammany',
#  'Terrebonne',
#  'Cumberland',
#  'Anne Arundel',
#  'Charles',
#  'Bay',
#  'Charlevoix',
#  'Leelanau',
#  'Macomb',
#  'Wright',
#  'Copiah',
#  'Leflore',
#  'Pearl River',
#  'Gallatin',
#  'Lewis and Clark',
#  'Silver Bow',
#  'Yellowstone',
#  'Ocean',
#  'Schenectady',
#  'Oklahoma',
#  'Chester',
#  'McCook',
#  'Hamilton',
#  'Rutherford',
#  'Bell',
#  'Galveston',
#  'Smith',
#  'Travis',
#  'Harrisonburg city',
#  'Grant',
#  'Milwaukee',
#  'Racine',
#  'Sheboygan',
#  'Fremont',
#  'Baldwin',
#  'Graham',
#  'San Luis Obispo',
#  'Boulder',
#  'Mesa',
#  'Hartford',
#  'New Haven',
#  'Coweta',
#  'Kauai',
#  'Blaine',
#  'Teton',
#  'DuPage',
#  'Sangamon',
#  'Woodford',
#  'LaPorte',
#  'Wells',
#  'Franklin',
#  'Bourbon',
#  'Nelson',
#  'Bossier',
#  'Lafourche',
#  'St. John the Baptist',
#  'Barnstable',
#  'Bristol',
#  'Renville',
#  'Missoula',
#  'Mercer',
#  'Sandoval',
#  'Broome',
#  'Tioga',
#  'Tompkins',
#  'Brunswick',
#  'Craven',
#  'Harnett',
#  'Belmont',
#  'Lorain',
#  'Tuscarawas',
#  'Allegheny',
#  'Beaufort',
#  'Lexington',
#  'Campbell',
#  'Brazoria',
#  'Hays',
#  'Windsor',
#  'Chesterfield',
#  'Spotsylvania',
#  'Klickitat',
#  'Winnebago',
#  'Garland',
#  'Saline',
#  'San Bernardino',
#  'Santa Barbara',
#  'Garfield',
#  'Baker',
#  'Citrus',
#  'Clarke',
#  'Clayton',
#  'Dougherty',
#  'Newton',
#  'Maui',
#  'Clinton',
#  'Whiteside',
#  'Allamakee',
#  'St. Bernard',
#  'Lincoln',
#  'Baltimore city',
#  'Hampden',
#  'Plymouth',
#  'Ottawa',
#  'Waseca',
#  'Hinds',
#  'Erie',
#  'Putnam',
#  'Watauga',
#  'Wilson',
#  'Lucas',
#  'Medina',
#  'Cleveland',
#  'Kay',
#  'Payne',
#  'Yamhill',
#  'Lehigh',
#  'Luzerne',
#  'Anderson',
#  'Greenville',
#  'Horry',
#  'Denton',
#  'Utah',
#  'Lewis',
#  'Fairbanks North Star Borough',
#  'Cleburne',
#  'Desha',
#  'Nevada',
#  'Escambia',
#  'Hall',
#  'Paulding',
#  'Troup',
#  'Peoria',
#  'Will',
#  'Bartholomew',
#  'Ascension',
#  'Frederick',
#  'Talbot',
#  'Benton',
#  'Blue Earth',
#  'Hancock',
#  'Hunterdon',
#  'Somerset',
#  'Allegany',
#  'Onondaga',
#  'Ontario',
#  'Durham',
#  'Geauga',
#  'Canadian',
#  'Sevier',
#  'Bowie',
#  'Matagorda',
#  'Tooele',
#  'Wasatch',
#  'Stafford',
#  'York',
#  'Outagamie',
#  'Wood',
#  'Madison',
#  'Ketchikan Gateway Borough',
#  'Navajo',
#  'Kern',
#  'Monterey',
#  'Sussex',
#  'Brevard',
#  'Richmond',
#  'Whitfield',
#  'Hawaii',
#  'Adair',
#  'Black Hawk',
#  'Ford',
#  'Lyon',
#  'East Baton Rouge',
#  'Kennebec',
#  'Oxford',
#  'Otsego',
#  'Martin',
#  'Nicollet',
#  'Cole',
#  'Sarpy',
#  'Gloucester',
#  'Warren',
#  'Taos',
#  'Rensselaer',
#  'Wyoming',
#  'Iredell',
#  'Sampson',
#  'Burleigh',
#  'Coshocton',
#  'Darke',
#  'Mahoning',
#  'Pawnee',
#  'Lane',
#  'Beaver',
#  'Calhoun',
#  'Richland',
#  'Brazos',
#  'Ellis',
#  'Lubbock',
#  'Charlottesville city',
#  'Goochland',
#  'Henrico',
#  'Williamsburg city',
#  'Mason',
#  'Kenosha',
#  'Laramie',
#  'Park',
#  'Talladega',
#  'Kenai Peninsula Borough',
#  'Coconino',
#  'Bradley',
#  'Faulkner',
#  'Mendocino',
#  'Yuma',
#  'Leon',
#  'Sumter',
#  'Walton',
#  'Houston',
#  'Twin Falls',
#  'Kankakee',
#  'Kendall',
#  'LaSalle',
#  'Jennings',
#  'Winneshiek',
#  'Leavenworth',
#  'Kenton',
#  'Penobscot',
#  'Rice',
#  'Bolivar',
#  'Coahoma',
#  'DeSoto',
#  'Perry',
#  'St. Louis city',
#  'Belknap',
#  'Merrimack',
#  'Atlantic',
#  'Chenango',
#  'Livingston',
#  'Gaston',
#  'Guilford',
#  'Hoke',
#  'Moore',
#  'New Hanover',
#  'Morton',
#  'Ashland',
#  'Huron',
#  'Miami',
#  'Berks',
#  'Lackawanna',
#  'Cheatham',
#  'Robertson',
#  'Sumner',
#  'Lavaca',
#  'McLennan',
#  'Rusk',
#  'Webb',
#  'Wichita',
#  'Box Elder',
#  'Cache',
#  'Charles City',
#  'Richmond city',
#  'Brown',
#  'La Crosse',
#  'Chambers',
#  'Mobile',
#  'Walker',
#  'Yavapai',
#  'Craighead',
#  'Crittenden',
#  'Independence',
#  'Poinsett',
#  'Pope',
#  'Searcy',
#  'Sebastian',
#  'Van Buren',
#  'Crowley',
#  'Grand',
#  'Morgan',
#  'Tolland',
#  'Windham',
#  'Hernando',
#  'Indian River',
#  'Bibb',
#  'Early',
#  'Effingham',
#  'Glynn',
#  'Laurens',
#  'Peach',
#  'Rockdale',
#  'Owen',
#  'Tippecanoe',
#  'Dubuque',
#  'Muscatine',
#  'Sedgwick',
#  'Christian',
#  'Daviess',
#  'Henderson',
#  'Scott',
#  'Assumption',
#  'Calcasieu',
#  'Iberia',
#  'Iberville',
#  'Lafayette',
#  'Plaquemines',
#  'St. James',
#  'St. Landry',
#  'Webster',
#  'West Baton Rouge',
#  'Calvert',
#  'Wicomico',
#  'Hampshire',
#  'Eaton',
#  'Genesee',
#  'Midland',
#  'Mower',
#  'Holmes',
#  'Jones',
#  'Walthall',
#  'Wilkinson',
#  'Winston',
#  'Yazoo',
#  'Broadwater',
#  'Flathead',
#  'Roosevelt',
#  'Nemaha',
#  'Elko',
#  'Cape May',
#  'San Miguel',
#  'Schoharie',
#  'Custer',
#  'Grady',
#  'Logan',
#  'McClain',
#  'Lebanon',
#  'Westmoreland',
#  'Abbeville',
#  'Dorchester',
#  'Saluda',
#  'Dyer',
#  'Cameron',
#  'Crane',
#  'DeWitt',
#  'Van Zandt',
#  'Clallam',
#  'Monongalia',
#  'Tucker',
#  'Bayfield',
#  'Calumet',
#  'Eau Claire',
#  'Ozaukee',
#  'Sauk',
#  'Walworth',
#  'Cullman',
#  'Lamar',
#  'Lauderdale',
#  'Amador',
#  'Imperial',
#  'Broomfield',
#  'New London',
#  'Dawson',
#  'Heard',
#  'Miller',
#  'Muscogee',
#  'Oconee',
#  'Pickens',
#  'Randolph',
#  'Spalding',
#  'Terrell',
#  'Tift',
#  'Turner',
#  'Worth',
#  'Bingham',
#  'Canyon',
#  'Kootenai',
#  'McLean',
#  'Allen',
#  'Vanderburgh',
#  'Vigo',
#  'Reno',
#  'Riley',
#  'Calloway',
#  'Catahoula',
#  'De Soto',
#  'Rapides',
#  'Tangipahoa',
#  'Chisago',
#  'Fillmore',
#  'Humphreys',
#  'Lawrence',
#  'Marshall',
#  'Rankin',
#  'Tippah',
#  'Dunklin',
#  'Kansas City',
#  'Buffalo',
#  'Nye',
#  'Cheshire',
#  'Doña Ana',
#  'McKinley',
#  'Niagara',
#  'Oneida',
#  'Carteret',
#  'Pasquotank',
#  'Pitt',
#  'Rowan',
#  'Stanly',
#  'Ashtabula',
#  'Columbiana',
#  'Garvin',
#  'Centre',
#  'Potter',
#  'Aiken',
#  'Berkeley',
#  'Clarendon',
#  'Darlington',
#  'Florence',
#  'Orangeburg',
#  'Blount',
#  'Dickson',
#  'Hamblen',
#  'Maury',
#  'Tipton',
#  'Fannin',
#  'Hockley',
#  'Upshur',
#  'Addison',
#  'Rutland',
#  'Accomack',
#  'Newport News city',
#  'Norfolk city',
#  'Portsmouth city',
#  'Cowlitz',
#  'San Juan',
#  'Stevens',
#  'Kanawha',
#  'Chippewa',
#  'Dunn',
#  'Green',
#  'Marathon',
#  'Rock',
#  'St. Croix',
#  'Natrona',
#  'Apache',
#  'Cochise',
#  'Butte',
#  'El Dorado',
#  'Siskiyou',
#  'Yuba',
#  'Chaffee',
#  'Elbert',
#  'Hinsdale',
#  'Montrose',
#  'Highlands',
#  'St. Lucie',
#  'Lumpkin',
#  'Elkhart',
#  'Story',
#  'Spencer',
#  'Avoyelles',
#  'Beauregard',
#  'Bienville',
#  'Claiborne',
#  'Evangeline',
#  'Ouachita',
#  'St. Mary',
#  'Sagadahoc',
#  'Caroline',
#  'Nantucket',
#  'Allegan',
#  'Barry',
#  'Berrien',
#  'Clare',
#  'Saginaw',
#  'Tuscola',
#  'Wexford',
#  'Dodge',
#  'Steele',
#  'Wabasha',
#  'Attala',
#  'George',
#  'Grenada',
#  'Itawamba',
#  'Leake',
#  'Panola',
#  'Simpson',
#  'Tunica',
#  'Bates',
#  'Jasper',
#  'Cascade',
#  'Ravalli',
#  'Strafford',
#  'Lea',
#  'Steuben',
#  'Buncombe',
#  'Catawba',
#  'Clermont',
#  'Defiance',
#  'Licking',
#  'Josephine',
#  'Montour',
#  'Dillon',
#  'Edgefield',
#  'Greenwood',
#  'Marlboro',
#  'Newberry',
#  'Cocke',
#  'Roane',
#  'Bastrop',
#  'Castro',
#  'Deaf Smith',
#  'Oldham',
#  'Albemarle',
#  'Botetourt',
#  'Isle of Wight',
#  'Suffolk city',
#  'Carbon',
#  'Bradford',
#  'Flagler',
#  'Barrow',
#  'Butts',
#  'Chattooga',
#  'Clinch',
#  'Coffee',
#  'Tattnall',
#  'Twiggs',
#  'Valley',
#  'Champaign',
#  'Jo Daviess',
#  'Rock Island',
#  'Stephenson',
#  'Ripley',
#  'Cerro Gordo',
#  'Kossuth',
#  'Poweshiek',
#  'Sioux',
#  'Tama',
#  'Woodbury',
#  'Mitchell',
#  'Breathitt',
#  'Hardin',
#  'Jessamine',
#  'Acadia',
#  'Cecil',
#  "St. Mary's",
#  'Emmet',
#  'Gladwin',
#  'Grand Traverse',
#  'Roscommon',
#  'Le Sueur',
#  'Chickasaw',
#  'Oktibbeha',
#  'Pontotoc',
#  'Sunflower',
#  'Tate',
#  'Salem',
#  'Cortland',
#  'St. Lawrence',
#  'Davie',
#  'Granville',
#  'Nash',
#  'Robeson',
#  'Scotland',
#  'Gallia',
#  'Portage',
#  'Muskogee',
#  'Dauphin',
#  'Schuylkill',
#  'Colleton',
#  'Gibson',
#  'Loudon',
#  'McMinn',
#  'Amherst',
#  'Bedford',
#  'Culpeper',
#  'Fluvanna',
#  'Louisa',
#  'Whitman',
#  'Tallapoosa',
#  'Juneau City and Borough',
#  'Matanuska-Susitna Borough',
#  'La Plata',
#  'Teller',
#  'Burke',
#  'Catoosa',
#  'Liberty',
#  'Dubois',
#  'Wapello',
#  'Natchitoches',
#  'St. Martin',
#  'Garrett',
#  "Queen Anne's",
#  'Kalamazoo',
#  'Muskegon',
#  'Newaygo',
#  'Big Stone',
#  'Lac qui Parle',
#  'Sherburne',
#  'Tallahatchie',
#  'Callaway',
#  'Moniteau',
#  'St. Francois',
#  'Taney',
#  'Chaves',
#  'Cayuga',
#  'Oswego',
#  'Alamance',
#  'Vance',
#  'Walsh',
#  'Sandusky',
#  'Hood River',
#  'Cambria',
#  'Georgetown',
#  'Codington',
#  'Hughes',
#  'Lyman',
#  'Pennington',
#  'Iron',
#  'Danville city',
#  'Rockbridge',
#  'Autauga',
#  'Conway',
#  'Crawford',
#  'Cross',
#  'Hot Spring',
#  'Stone',
#  'White',
#  'Woodruff',
#  'Calaveras',
#  'Merced',
#  'Mono',
#  'Delta',
#  'Huerfano',
#  'Ben Hill',
#  'Bryan',
#  'Colquitt',
#  'Crisp',
#  'Irwin',
#  'Macon',
#  'Meriwether',
#  'Stephens',
#  'Bannock',
#  'Cassia',
#  'Grundy',
#  'Dearborn',
#  'Decatur',
#  'Ohio',
#  'Porter',
#  'Starke',
#  'Warrick',
#  'Buchanan',
#  'Cedar',
#  'Doniphan',
#  'Pottawatomie',
#  'Woodson',
#  'McCracken',
#  'Menifee',
#  'Muhlenberg',
#  'Vernon',
#  'Waldo',
#  'Hillsdale',
#  'Isabella',
#  'Kalkaska',
#  'Lapeer',
#  'Manistee',
#  'Choctaw',
#  'Noxubee',
#  'Cape Girardeau',
#  'Pemiscot',
#  'Saunders',
#  'Cibola',
#  'Curry',
#  'Chemung',
#  'Transylvania',
#  'Highland',
#  'Mayes',
#  'Wagoner',
#  'Clatsop',
#  'Armstrong',
#  'Clearfield',
#  'Juniata',
#  'Brookings',
#  'Overton',
#  'Comal',
#  'Falls',
#  'Grayson',
#  'Hidalgo',
#  'Nueces',
#  'Parker',
#  'Victoria',
#  'Caledonia',
#  'Chesapeake city',
#  'Halifax',
#  'Preston',
#  'Sweetwater',
#  'Chilton',
#  'Colbert',
#  'Etowah',
#  'Russell',
#  'Wilcox',
#  'Drew',
#  'Inyo',
#  'Sutter',
#  'Otero',
#  'Gadsden',
#  'Long',
#  'Taylor',
#  'Thomas',
#  'Ware',
#  'Wilkes',
#  'Idaho',
#  'Nez Perce',
#  'Payette',
#  'Rush',
#  'Neosho',
#  'Shawnee',
#  'Laurel',
#  'McCreary',
#  'Jefferson Davis',
#  'Morehouse',
#  'Winn',
#  'Dukes',
#  'Iosco',
#  'Lenawee',
#  'Marquette',
#  'Sanilac',
#  'Goodhue',
#  'Winona',
#  'Prentiss',
#  'Cooper',
#  'McDonald',
#  'Platte',
#  'Ralls',
#  'Hill',
#  'Eddy',
#  'Rio Arriba',
#  'Chautauqua',
#  'Bertie',
#  'Caldwell',
#  'Duplin',
#  'Hertford',
#  'Lenoir',
#  'McDowell',
#  'Foster',
#  'Pickaway',
#  'Seneca',
#  'Carter',
#  'Creek',
#  'Osage',
#  'Lycoming',
#  'Newport',
#  'Providence',
#  'Williamsburg',
#  'Meade',
#  'Hawkins',
#  'Atascosa',
#  'Austin',
#  'Blanco',
#  'Burnet',
#  'Coryell',
#  ...]
